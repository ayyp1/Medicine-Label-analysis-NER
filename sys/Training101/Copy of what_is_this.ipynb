# %%
import spacy

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2024-01-11 11:35:20.315538: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-11 11:35:20.315640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-11 11:35:20.318935: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-11 11:35:22.067299: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load("en_core_web_lg")
nlp

# %%
import json
with open('/content/combined_annotations.json', 'r') as f:
  data = json.load(f)

# %%
data['annotations'][0]
# Out:
# ['Image 1: Acid-labletsBP MEFTAL-500 Each Uncoated Tablet Contains: 500 mg Mefenamic Acid IP MET-EETTEO Excipients q.s. Dosage:As prescribed by the Physician Store protected from light & moisture at a temperature not exceeding 30C 205208 Keep out of reach of children. Registered Trademark BLUE MADE IN INDIA BY BLUE CROSS LABORATORIES PVTLTD L-17.VERNA INDUSTRIAL ESTATE VERNA.GOA403 722 CROSS Regd OPeninsula Chambers.G.K Mag Mumbai400 013. Rx Mefenamic AcidTablets:BP CCAo LOROURS MEFTAL-500 ',
#  {'entities': [[24, 34, 'COMMON NAME'], [66, 90, 'COMPOSITION NAME']]}]

# %%
data['annotations'][0][1].keys()
# Out:
# dict_keys(['entities'])

# %%
data['annotations'][0][1]['entities']
# Out:
# [[24, 34, 'COMMON NAME'], [66, 90, 'COMPOSITION NAME']]

# %%
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en") # load a new spacy model
db = DocBin() # create a DocBin object

# %%
for item in data['annotations']:
    if item is None:
        print("Found None value in data['annotations']")
    else:
        print(item)
        text, annot = item
# Out:
# ['Image 1: Acid-labletsBP MEFTAL-500 Each Uncoated Tablet Contains: 500 mg Mefenamic Acid IP MET-EETTEO Excipients q.s. Dosage:As prescribed by the Physician Store protected from light & moisture at a temperature not exceeding 30C 205208 Keep out of reach of children. Registered Trademark BLUE MADE IN INDIA BY BLUE CROSS LABORATORIES PVTLTD L-17.VERNA INDUSTRIAL ESTATE VERNA.GOA403 722 CROSS Regd OPeninsula Chambers.G.K Mag Mumbai400 013. Rx Mefenamic AcidTablets:BP CCAo LOROURS MEFTAL-500 ', {'entities': [[24, 34, 'COMMON NAME'], [66, 90, 'COMPOSITION NAME']]}]
# ...

# %%
for text, annot in tqdm(data['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("./training_data.spacy") # save the docbin object
# Out:
# 100%|██████████| 360/360 [00:00<00:00, 2179.60it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2024-01-11 11:50:37.203769: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-11 11:50:37.203837: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-11 11:50:37.205307: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-11 11:50:38.586955: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
! python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# 2024-01-11 11:51:26.568871: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-11 11:51:26.568952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-11 11:51:26.570592: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-11 11:51:27.960816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ...

# %%
nlp_ner = spacy.load("/content/model-best")

# %%
doc = nlp_ner('Image 436: NIMS" NIMS- NIMS NIMESULIDE TABLETS NIMS Fxcn untsated tabe contains Wresuideep s00mg TrtyMaryaecsered eepalt Asian Prarmaceuticals Pvt.Ltd Omsatrysp/.Rupandehi NIMS NIMS NIMS ')

# %%
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Image 436: NIMS&quot; NIMS- NIMS NIMESULIDE TABLETS NIMS Fxcn untsated tabe contains Wresuideep s00mg TrtyMaryaecsered eepalt Asian Prarmaceuticals Pvt.Ltd Omsatrysp/.Rupandehi NIMS NIMS NIMS </div></span>

# %%
doc_pop = nlp_ner('Image 330: ALPINE-LH Each uncoated bilayered tablet contains Losartan Potassium BP 25 mg 922h Amlodipine Besylate BP eq to Amlodipine 5 mg Colour:Tartrazine R Araurft f-fa NIMBUS NIMBUS (A division of LOMUS) ALPINE-LH ALPINE-LH ALPINE-LH Losartan Potassium & Amlodipine Tablets IP ALPINE-LH ')

# %%
spacy.displacy.render(doc_pop, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Image 330: ALPINE-LH Each uncoated bilayered tablet contains Losartan Potassium BP 25 mg 922h Amlodipine Besylate BP eq to Amlodipine 5 mg Colour:Tartrazine R Araurft f-fa NIMBUS NIMBUS (A division of LOMUS) ALPINE-LH ALPINE-LH ALPINE-LH
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Losartan Potassium &amp; Amlodipine Tablets IP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOSITION NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALPINE-LH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMMON NAME</span>
# ...

# %%
docks = nlp_ner('Image 407: Ferrous Ascorbate,Folic Acid  Zinc Sulphate Tablets XT R.B.TONE Each film coated tablet contains Ferrous Ascorbate I.P. equivalent to Elemental Iron 100mg Folic Acid I.P. 1500mcg Zinc Sulphate Monohydrate l.P 61.8mg equivalent to Elemental Zinc 22.5mg Colours:Ponceau 4R Lake and Titanium Dioxide I.P. Dosage :Adults 1 tablet daily or as directed by the Physician Storage:Store protected from moisture,at temperature not exceeding 30C Rogistored Trademark ')

# %%
spacy.displacy.render(docks, style="ent", jupyter=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Image 407: Ferrous Ascorbate,Folic Acid  Zinc Sulphate Tablets XT R.B.TONE Each film coated tablet contains Ferrous Ascorbate I.P. equivalent to Elemental Iron 100mg Folic Acid I.P. 1500mcg Zinc Sulphate Monohydrate l.P 61.8mg equivalent to Elemental Zinc 22.5mg Colours:Ponceau 4R Lake and Titanium Dioxide I.P. Dosage :Adults 1 tablet daily or as directed by the Physician Storage:Store protected from moisture,at temperature not exceeding 30C Rogistored Trademark </div></span>

# %%
import json
with open('/content/annotations-351-436.json', 'r') as f:
  testing_data = json.load(f)

# %%
for text, annot in tqdm(testing_data['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("./testing_data.spacy") # save the docbin object
# Out:
# 100%|██████████| 97/97 [00:00<00:00, 843.71it/s]

# %%
# !python -m spacy evaluate /content/model-best /content/testing_data.spacy
# Out:
# 2024-01-11 14:31:29.764593: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-11 14:31:29.764665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-11 14:31:29.766097: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-11 14:31:31.175922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Using CPU
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   93.16
# NER R   92.73
# NER F   92.94
# SPEED   3103
#
#
# ...
